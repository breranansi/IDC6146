# %% [markdown]
# # Optimizer Example
# Jena Climate ANN example showing comparison between optimizers.
# This is a regression model, using 3-hour data.
#
# Richard Henry, 26-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
plt.style.use('fivethirtyeight')

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.17.0'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# |Dataset|Architecture|Group|Type|
# |---|---|---|---|
# |Jena3|ANN|Contemporary|Regression|

# %%
# Load Data (Already cleaned and decimated)
df3=pd.read_csv('dataset/Jena_climate/cleanJena3.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23363 entries, 0 to 23362
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   p (mbar)       23363 non-null  float64
#  1   VPact (mbar)   23363 non-null  float64
#  2   Tdew (degC)    23363 non-null  float64
#  3   T (degC)       23363 non-null  float64
#  4   max. wv (m/s)  23363 non-null  float64
#  5   NSwind         23363 non-null  float64
#  6   EWwind         23363 non-null  float64
#  7   year           23363 non-null  int64
#  8   month          23363 non-null  int64
#  9   day            23363 non-null  int64
#  10  hour           23363 non-null  int64
# dtypes: float64(7), int64(4)
# memory usage: 2.0 MB

# %%
df3.describe()
# Out:
#            p (mbar)  VPact (mbar)   Tdew (degC)      T (degC)  max. wv (m/s)  \
# count  23363.000000  23363.000000  23363.000000  23363.000000   23363.000000
# mean     989.216246      9.533017      4.954671      9.456338       3.533382
# std        8.353071      4.184973      6.730860      8.428081       2.339862
# min      942.720000      0.810000    -24.800000    -22.760000       0.000000
# 25%      984.200000      6.220000      0.240000      3.340000       1.760000
# 50%      989.590000      8.860000      5.210000      9.440000       2.980000
# 75%      994.730000     12.360000     10.080000     15.480000       4.730000
# max     1015.170000     28.040000     22.940000     36.460000      18.780000
#
#              NSwind        EWwind          year         month           day  \
# count  23363.000000  23363.000000  23363.000000  23363.000000  23363.000000
# mean      -0.631798     -0.415655   2012.497068      6.517399     15.713222
# std        1.983549      1.553730      2.289905      3.448433      8.799298
# min      -10.783959     -7.148867   2009.000000      1.000000      1.000000
# 25%       -1.480647     -1.372670   2010.000000      4.000000      8.000000
# 50%       -0.637933     -0.296919   2012.000000      7.000000     16.000000
# 75%        0.306138      0.432981   2014.000000     10.000000     23.000000
# max        7.709359      6.966350   2017.000000     12.000000     31.000000
#
#                hour
# count  23363.000000
# mean      10.500449
# std        6.873702
# min        0.000000
# 25%        6.000000
# 50%       12.000000
# 75%       15.000000
# max       21.000000

# %%
# Model / data parameters
blk_len=16*8      #Look back at two weeks of data
stp_len=8         #look forward 24 hours
row_len=len(df3)   #total records (last target location)
col_len=11         #total variables
bat_len=64*8      #batch size of 2 months
epo_len=32         #32 epochs
val_fra=0.2        #use 20% of data for validation
pas_len=blk_len+stp_len  #first target location
cut_len=row_len-pas_len  #last start of predictor location

# %%
# %%time
# Reformat
y_train=df3['T (degC)'].iloc[pas_len:].to_numpy()  #pull out all the targets
#start building predictor deck
xAll=df3.to_numpy()
xTrain=np.zeros([cut_len,blk_len,col_len])
for i in range(cut_len):
    for j in range(blk_len):
            xTrain[i][j][:]=xAll[i+j][:]
# Out:
# CPU times: total: 2.03 s
# Wall time: 2.77 s

# %%
#Normalize Input Data
fixMe=tf.keras.layers.Normalization()
fixMe.adapt(xTrain)

# %%
# Build & train model functions
def model_core():
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=(blk_len,col_len)),
            fixMe,
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(64,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(1,
                                  activation='linear')
        ]
    )
    return model
def model_build(myOpti):
    #Build it exactly the same every time
    tf.random.set_seed(19)
    model=model_core()
    model.compile(loss='mean_squared_error',
                  optimizer=myOpti,
                  metrics=['mean_absolute_error'])
    # Reduce variation in training...
    tf.random.set_seed(17)
    print("History Match:")
    myHis=model.fit(xTrain,
                    y_train,
                    batch_size=bat_len,
                    epochs=epo_len,
                    validation_split=val_fra)
    print("\n")
    print("Evaluate Model:")
    myEva=model.evaluate(xTrain,
                         y_train,
                         batch_size=bat_len)
    print("All Sample MSE:",myEva[0])
    print("All Sample MAE:",myEva[1])
    print("\n")
    print("Make Predictions:")
    myPre=model.predict(xTrain)
    print("\n")
    print("Timing:")
    return myHis,myPre

# %% [markdown]
# ### First Model, Adam

# %%
# %%time
h0,p0=model_build('adam')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 108.9109 - mean_absolute_error: 8.4057 - val_loss: 47.0977 - val_mean_absolute_error: 5.5684
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 32.0921 - mean_absolute_error: 4.4747 - val_loss: 20.5395 - val_mean_absolute_error: 3.6145
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.9253 - mean_absolute_error: 3.7511 - val_loss: 14.7246 - val_mean_absolute_error: 3.0506
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.3476 - mean_absolute_error: 3.4330 - val_loss: 13.6790 - val_mean_absolute_error: 2.9312
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.1850 - mean_absolute_error: 3.2463 - val_loss: 13.4796 - val_mean_absolute_error: 2.8879
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.2056 - mean_absolute_error: 3.1437 - val_loss: 12.6043 - val_mean_absolute_error: 2.7908
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.5314 - mean_absolute_error: 3.0552 - val_loss: 13.0741 - val_mean_absolute_error: 2.8447
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.7965 - mean_absolute_error: 2.9858 - val_loss: 12.7279 - val_mean_absolute_error: 2.7874
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.0479 - mean_absolute_error: 2.9055 - val_loss: 13.2638 - val_mean_absolute_error: 2.8624
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.5460 - mean_absolute_error: 2.8522 - val_loss: 12.4330 - val_mean_absolute_error: 2.7635
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.5331 - mean_absolute_error: 2.8444 - val_loss: 12.7254 - val_mean_absolute_error: 2.8088
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.1552 - mean_absolute_error: 2.8009 - val_loss: 12.5683 - val_mean_absolute_error: 2.7813
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.0476 - mean_absolute_error: 2.7930 - val_loss: 12.9287 - val_mean_absolute_error: 2.8207
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.6470 - mean_absolute_error: 2.7501 - val_loss: 12.4929 - val_mean_absolute_error: 2.7682
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.6071 - mean_absolute_error: 2.7436 - val_loss: 13.8515 - val_mean_absolute_error: 2.9419
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.3190 - mean_absolute_error: 2.7037 - val_loss: 12.8916 - val_mean_absolute_error: 2.8146
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.0061 - mean_absolute_error: 2.6628 - val_loss: 13.1184 - val_mean_absolute_error: 2.8335
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.0073 - mean_absolute_error: 2.6632 - val_loss: 12.7678 - val_mean_absolute_error: 2.8011
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.8551 - mean_absolute_error: 2.6634 - val_loss: 13.7264 - val_mean_absolute_error: 2.9369
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.3417 - mean_absolute_error: 2.5982 - val_loss: 13.4709 - val_mean_absolute_error: 2.8942
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2144 - mean_absolute_error: 2.5839 - val_loss: 12.7465 - val_mean_absolute_error: 2.8118
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2415 - mean_absolute_error: 2.5855 - val_loss: 12.6135 - val_mean_absolute_error: 2.7863
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2583 - mean_absolute_error: 2.5791 - val_loss: 12.8424 - val_mean_absolute_error: 2.8119
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1526 - mean_absolute_error: 2.5769 - val_loss: 13.1121 - val_mean_absolute_error: 2.8589
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.8665 - mean_absolute_error: 2.5253 - val_loss: 12.5396 - val_mean_absolute_error: 2.7793
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4763 - mean_absolute_error: 2.4832 - val_loss: 12.9166 - val_mean_absolute_error: 2.8384
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.4247 - mean_absolute_error: 2.4897 - val_loss: 12.8530 - val_mean_absolute_error: 2.8262
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.6598 - mean_absolute_error: 2.4988 - val_loss: 12.6901 - val_mean_absolute_error: 2.8077
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4504 - mean_absolute_error: 2.4718 - val_loss: 13.1305 - val_mean_absolute_error: 2.8663
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3187 - mean_absolute_error: 2.4658 - val_loss: 12.6658 - val_mean_absolute_error: 2.8111
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.2239 - mean_absolute_error: 2.4488 - val_loss: 13.5186 - val_mean_absolute_error: 2.9257
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3547 - mean_absolute_error: 2.4669 - val_loss: 12.9629 - val_mean_absolute_error: 2.8556
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1771 - mean_absolute_error: 1.7632
# All Sample MSE: 6.5934858322143555
# All Sample MAE: 1.966245174407959
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step
#
#
# Timing:
# CPU times: total: 4.41 s
# Wall time: 9.25 s

# %%
plt.figure(figsize=(13.33, 6.67))
plt.plot(h0.history['val_loss'])
plt.plot(h0.history['loss'])
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['validation','training'])
plt.title('Adam\nJena ANN')
plt.grid(color='white')
plt.show()

# %%
plt.figure(figsize=(13.33, 6.67))
plt.plot(y_train)
plt.plot(p0.flatten())
plt.ylabel('Temperature [degC]')
plt.xlabel('Hour')
plt.legend(['training','prediction'])
plt.title('Adam\nJena ANN')
plt.grid(color='white')
plt.show()

# %%
plt.figure(figsize=(13.33, 6.67))
plt.scatter(y_train,p0.flatten())
plt.ylabel('Estimated Temperature [degC]')
plt.xlabel('Measured Temperature [degC]')
plt.title('Adam\nJena ANN')
plt.grid(color='white')
plt.xlim([-22,38])
plt.ylim([-22,38])
plt.show()

# %% [markdown]
# ### Second Model, AdaGrad

# %%
# %%time
h1,p1=model_build('adagrad')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 86.0044 - mean_absolute_error: 7.4136 - val_loss: 54.1075 - val_mean_absolute_error: 5.8896
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 38.2600 - mean_absolute_error: 4.8825 - val_loss: 37.5073 - val_mean_absolute_error: 4.8417
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 32.4782 - mean_absolute_error: 4.4976 - val_loss: 28.6785 - val_mean_absolute_error: 4.2198
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 28.2466 - mean_absolute_error: 4.1890 - val_loss: 24.1644 - val_mean_absolute_error: 3.8815
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 26.2214 - mean_absolute_error: 4.0231 - val_loss: 22.1324 - val_mean_absolute_error: 3.7249
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.6868 - mean_absolute_error: 3.9018 - val_loss: 20.8744 - val_mean_absolute_error: 3.6243
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 23.5947 - mean_absolute_error: 3.8364 - val_loss: 20.1383 - val_mean_absolute_error: 3.5676
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.7058 - mean_absolute_error: 3.7402 - val_loss: 19.5730 - val_mean_absolute_error: 3.5243
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 22.0776 - mean_absolute_error: 3.6933 - val_loss: 19.0533 - val_mean_absolute_error: 3.4826
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.3917 - mean_absolute_error: 3.6218 - val_loss: 18.6949 - val_mean_absolute_error: 3.4495
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.9003 - mean_absolute_error: 3.5962 - val_loss: 18.3301 - val_mean_absolute_error: 3.4175
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.6689 - mean_absolute_error: 3.5664 - val_loss: 17.9643 - val_mean_absolute_error: 3.3808
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 20.0609 - mean_absolute_error: 3.5290 - val_loss: 17.6563 - val_mean_absolute_error: 3.3506
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.6694 - mean_absolute_error: 3.4904 - val_loss: 17.3946 - val_mean_absolute_error: 3.3290
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.0918 - mean_absolute_error: 3.4311 - val_loss: 17.1638 - val_mean_absolute_error: 3.3075
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.4977 - mean_absolute_error: 3.4756 - val_loss: 16.8543 - val_mean_absolute_error: 3.2749
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.9351 - mean_absolute_error: 3.4228 - val_loss: 16.5070 - val_mean_absolute_error: 3.2380
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.4831 - mean_absolute_error: 3.3647 - val_loss: 16.4308 - val_mean_absolute_error: 3.2363
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.4604 - mean_absolute_error: 3.3682 - val_loss: 16.1252 - val_mean_absolute_error: 3.2042
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2465 - mean_absolute_error: 3.3601 - val_loss: 15.8167 - val_mean_absolute_error: 3.1709
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 18.2757 - mean_absolute_error: 3.3498 - val_loss: 15.6103 - val_mean_absolute_error: 3.1476
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.9450 - mean_absolute_error: 3.3211 - val_loss: 15.5179 - val_mean_absolute_error: 3.1415
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.6410 - mean_absolute_error: 3.2909 - val_loss: 15.2772 - val_mean_absolute_error: 3.1159
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.4085 - mean_absolute_error: 3.2688 - val_loss: 15.0815 - val_mean_absolute_error: 3.0938
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.5903 - mean_absolute_error: 3.2698 - val_loss: 15.0507 - val_mean_absolute_error: 3.0934
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.7659 - mean_absolute_error: 3.3193 - val_loss: 14.9541 - val_mean_absolute_error: 3.0864
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.0404 - mean_absolute_error: 3.2303 - val_loss: 14.9226 - val_mean_absolute_error: 3.0851
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 17.0035 - mean_absolute_error: 3.2385 - val_loss: 14.6775 - val_mean_absolute_error: 3.0534
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0673 - mean_absolute_error: 3.2475 - val_loss: 14.5077 - val_mean_absolute_error: 3.0332
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.8557 - mean_absolute_error: 3.2094 - val_loss: 14.6705 - val_mean_absolute_error: 3.0608
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.8113 - mean_absolute_error: 3.2098 - val_loss: 14.3952 - val_mean_absolute_error: 3.0278
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 16.3359 - mean_absolute_error: 3.1926 - val_loss: 14.2359 - val_mean_absolute_error: 3.0082
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11.0270 - mean_absolute_error: 2.6044
# All Sample MSE: 11.746642112731934
# All Sample MAE: 2.6980292797088623
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 732us/step
#
#
# Timing:
# CPU times: total: 3.78 s
# Wall time: 7.92 s

# %% [markdown]
# ### Third Model, Stochastic Gradient Descent with Nesterov Momentum

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %%
# %%time
h2,p2=model_build(opt012)
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - mean_absolute_error: nan
# All Sample MSE: nan
# All Sample MAE: nan
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 740us/step
#
#
# Timing:
# CPU times: total: 3.92 s
# Wall time: 7.88 s

# %% [markdown]
# ### Fourth Model, Root Mean Squared Propagation

# %%
# %%time
h3,p3=model_build('rmsprop')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 68.0908 - mean_absolute_error: 6.3588 - val_loss: 19.3361 - val_mean_absolute_error: 3.5023
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.0460 - mean_absolute_error: 3.5991 - val_loss: 15.6840 - val_mean_absolute_error: 3.1346
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6269 - mean_absolute_error: 3.2667 - val_loss: 14.3530 - val_mean_absolute_error: 3.0314
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.6944 - mean_absolute_error: 3.1038 - val_loss: 15.9076 - val_mean_absolute_error: 3.1377
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.2309 - mean_absolute_error: 3.0575 - val_loss: 14.2196 - val_mean_absolute_error: 2.9596
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 15.0390 - mean_absolute_error: 3.0230 - val_loss: 15.4427 - val_mean_absolute_error: 3.0937
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 14.3108 - mean_absolute_error: 2.9384 - val_loss: 13.8863 - val_mean_absolute_error: 2.9374
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.4895 - mean_absolute_error: 2.8605 - val_loss: 12.7916 - val_mean_absolute_error: 2.8013
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.1756 - mean_absolute_error: 2.8178 - val_loss: 13.8910 - val_mean_absolute_error: 2.9472
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13.3788 - mean_absolute_error: 2.8447 - val_loss: 12.9064 - val_mean_absolute_error: 2.8384
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.6121 - mean_absolute_error: 2.7573 - val_loss: 13.5184 - val_mean_absolute_error: 2.8816
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.1930 - mean_absolute_error: 2.6976 - val_loss: 14.0812 - val_mean_absolute_error: 2.9793
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12.1431 - mean_absolute_error: 2.6927 - val_loss: 12.8855 - val_mean_absolute_error: 2.8125
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.8011 - mean_absolute_error: 2.6718 - val_loss: 13.4297 - val_mean_absolute_error: 2.9063
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.3027 - mean_absolute_error: 2.6039 - val_loss: 13.5751 - val_mean_absolute_error: 2.8952
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.6930 - mean_absolute_error: 2.6442 - val_loss: 13.6907 - val_mean_absolute_error: 2.8944
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.4484 - mean_absolute_error: 2.6082 - val_loss: 14.0540 - val_mean_absolute_error: 2.9362
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1311 - mean_absolute_error: 2.5878 - val_loss: 14.1488 - val_mean_absolute_error: 2.9576
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.1194 - mean_absolute_error: 2.5790 - val_loss: 13.2293 - val_mean_absolute_error: 2.8533
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.8625 - mean_absolute_error: 2.5427 - val_loss: 12.6400 - val_mean_absolute_error: 2.7902
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.7003 - mean_absolute_error: 2.5186 - val_loss: 13.2951 - val_mean_absolute_error: 2.8801
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.5783 - mean_absolute_error: 2.5111 - val_loss: 12.6895 - val_mean_absolute_error: 2.8151
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5352 - mean_absolute_error: 2.4849 - val_loss: 12.6374 - val_mean_absolute_error: 2.7878
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4195 - mean_absolute_error: 2.4847 - val_loss: 13.2597 - val_mean_absolute_error: 2.8568
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5443 - mean_absolute_error: 2.5143 - val_loss: 14.3221 - val_mean_absolute_error: 2.9522
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.4802 - mean_absolute_error: 2.4874 - val_loss: 13.9538 - val_mean_absolute_error: 2.9301
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.1203 - mean_absolute_error: 2.4626 - val_loss: 12.3585 - val_mean_absolute_error: 2.7443
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8908 - mean_absolute_error: 2.4294 - val_loss: 13.8559 - val_mean_absolute_error: 2.9513
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.2775 - mean_absolute_error: 2.4717 - val_loss: 13.3513 - val_mean_absolute_error: 2.8709
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8328 - mean_absolute_error: 2.4201 - val_loss: 14.7916 - val_mean_absolute_error: 3.0230
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0003 - mean_absolute_error: 2.4299 - val_loss: 15.5929 - val_mean_absolute_error: 3.1726
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8425 - mean_absolute_error: 2.4138 - val_loss: 14.6314 - val_mean_absolute_error: 3.0606
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7193 - mean_absolute_error: 1.8568
# All Sample MSE: 7.24937629699707
# All Sample MAE: 2.062741994857788
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 802us/step
#
#
# Timing:
# CPU times: total: 3.91 s
# Wall time: 8.01 s

# %%
plt.figure(figsize=(13.33, 6.67))
plt.plot(h0.history['val_loss'])
plt.plot(h1.history['val_loss'])
plt.plot(h2.history['val_loss'])
plt.plot(h3.history['val_loss'])
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('Jena ANN')
plt.grid(color='white')
plt.show()

# %%
plt.figure(figsize=(13.33, 6.67))
plt.plot(h0.history['val_loss'])
plt.plot(h1.history['val_loss'])
plt.plot(h2.history['val_loss'])
plt.plot(h3.history['val_loss'])
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('Jena ANN')
plt.ylim([10,20])
plt.grid(color='white')
plt.show()

# %% [markdown]
# ### Model Summary

# %%
m=model_core()
m.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)        │ (None, 128, 11)             │              23 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 1408)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 64)                  │          90,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 92,312 (360.60 KB)
#  Trainable params: 92,289 (360.50 KB)
#  Non-trainable params: 23 (96.00 B)
