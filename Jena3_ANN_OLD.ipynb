# %% [markdown]
# # Optimizer Example
# Jena Climate ANN example showing comparison between optimizers.
# This is a regression model, using 3-hour data.
#
# Richard Henry, 26-Jul-2024

# %%
#Import Libararies
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
plt.style.use('fivethirtyeight')

# %% [markdown]
# Test Libraries

# %%
# Check python version
from platform import python_version
print(python_version())
#3.12.3
# Out:
# 3.12.3

# %%
# Check tensorflow version
tf.__version__
#2.16.1
# Out:
# '2.17.0'

# %%
# Check keras version
tf.keras.__version__
#3.4.1
# Out:
# '3.4.1'

# %% [markdown]
# |Dataset|Architecture|Group|Type|
# |---|---|---|---|
# |Jena3|ANN|Contemporary|Regression|

# %%
# Load Data (Already cleaned and decimated)
df3=pd.read_csv('dataset/Jena_climate/cleanJena3.csv')

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23363 entries, 0 to 23362
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   p (mbar)       23363 non-null  float64
#  1   VPact (mbar)   23363 non-null  float64
#  2   Tdew (degC)    23363 non-null  float64
#  3   T (degC)       23363 non-null  float64
#  4   max. wv (m/s)  23363 non-null  float64
#  5   NSwind         23363 non-null  float64
#  6   EWwind         23363 non-null  float64
#  7   year           23363 non-null  int64
#  8   month          23363 non-null  int64
#  9   day            23363 non-null  int64
#  10  hour           23363 non-null  int64
# dtypes: float64(7), int64(4)
# memory usage: 2.0 MB

# %%
df3.describe()
# Out:
#            p (mbar)  VPact (mbar)   Tdew (degC)      T (degC)  max. wv (m/s)  \
# count  23363.000000  23363.000000  23363.000000  23363.000000   23363.000000
# mean     989.216246      9.533017      4.954671      9.456338       3.533382
# std        8.353071      4.184973      6.730860      8.428081       2.339862
# min      942.720000      0.810000    -24.800000    -22.760000       0.000000
# 25%      984.200000      6.220000      0.240000      3.340000       1.760000
# 50%      989.590000      8.860000      5.210000      9.440000       2.980000
# 75%      994.730000     12.360000     10.080000     15.480000       4.730000
# max     1015.170000     28.040000     22.940000     36.460000      18.780000
#
#              NSwind        EWwind          year         month           day  \
# count  23363.000000  23363.000000  23363.000000  23363.000000  23363.000000
# mean      -0.631798     -0.415655   2012.497068      6.517399     15.713222
# std        1.983549      1.553730      2.289905      3.448433      8.799298
# min      -10.783959     -7.148867   2009.000000      1.000000      1.000000
# 25%       -1.480647     -1.372670   2010.000000      4.000000      8.000000
# 50%       -0.637933     -0.296919   2012.000000      7.000000     16.000000
# 75%        0.306138      0.432981   2014.000000     10.000000     23.000000
# max        7.709359      6.966350   2017.000000     12.000000     31.000000
#
#                hour
# count  23363.000000
# mean      10.500449
# std        6.873702
# min        0.000000
# 25%        6.000000
# 50%       12.000000
# 75%       15.000000
# max       21.000000

# %%
# Model / data parameters
blk_len=16*8      #Look back at two weeks of data
stp_len=8         #look forward 24 hours
row_len=len(df3)   #total records (last target location)
col_len=11         #total variables
bat_len=64*8      #batch size of 2 months
epo_len=32         #32 epochs
val_fra=0.2        #use 20% of data for validation
pas_len=blk_len+stp_len  #first target location
cut_len=row_len-pas_len  #last start of predictor location

# %%
# %%time
# Reformat
y_train=df3['T (degC)'].iloc[pas_len:].to_numpy()  #pull out all the targets
#start building predictor deck
xAll=df3.to_numpy()
xTrain=np.zeros([cut_len,blk_len,col_len])
for i in range(cut_len):
    for j in range(blk_len):
            xTrain[i][j][:]=xAll[i+j][:]
# Out:
# CPU times: total: 2.16 s
# Wall time: 2.84 s

# %%
#Normalize Input Data
fixMe=tf.keras.layers.Normalization()
fixMe.adapt(xTrain)

# %%
# Build & train model functions
def model_core():
    model = tf.keras.Sequential(
        [
            tf.keras.Input(shape=(blk_len,col_len)),
            fixMe,
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(64,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(32,
                                  activation='relu'),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Dense(1,
                                  activation='linear')
        ]
    )
    return model
def model_build(myOpti):
    #Build it exactly the same every time
    tf.random.set_seed(19)
    model=model_core()
    model.compile(loss='mean_squared_error',
                  optimizer=myOpti,
                  metrics=['mean_absolute_error'])
    # Reduce variation in training...
    tf.random.set_seed(17)
    print("History Match:")
    myHis=model.fit(xTrain,
                    y_train,
                    batch_size=bat_len,
                    epochs=epo_len,
                    validation_split=val_fra)
    print("\n")
    print("Evaluate Model:")
    myEva=model.evaluate(xTrain,
                         y_train,
                         batch_size=bat_len)
    print("All Sample MSE:",myEva[0])
    print("All Sample MAE:",myEva[1])
    print("\n")
    print("Make Predictions:")
    myPre=model.predict(xTrain)
    print("\n")
    print("Timing:")
    return myHis,myPre

# %% [markdown]
# ### First Model, Adam

# %%
# %%time
h0,p0=model_build('adam')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 98.6186 - mean_absolute_error: 7.8553 - val_loss: 26.4510 - val_mean_absolute_error: 4.0486
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.4813 - mean_absolute_error: 4.1211 - val_loss: 16.2547 - val_mean_absolute_error: 3.1997
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 20.7685 - mean_absolute_error: 3.5793 - val_loss: 13.8062 - val_mean_absolute_error: 2.9547
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.6291 - mean_absolute_error: 3.2744 - val_loss: 12.7257 - val_mean_absolute_error: 2.8299
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 15.9255 - mean_absolute_error: 3.1184 - val_loss: 13.3873 - val_mean_absolute_error: 2.8979
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.9149 - mean_absolute_error: 3.0119 - val_loss: 12.7788 - val_mean_absolute_error: 2.8180
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 14.0151 - mean_absolute_error: 2.9195 - val_loss: 12.5243 - val_mean_absolute_error: 2.7869
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.6999 - mean_absolute_error: 2.8854 - val_loss: 12.6894 - val_mean_absolute_error: 2.8062
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13.1439 - mean_absolute_error: 2.8240 - val_loss: 12.5096 - val_mean_absolute_error: 2.7679
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.5494 - mean_absolute_error: 2.7627 - val_loss: 12.5858 - val_mean_absolute_error: 2.7776
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.5104 - mean_absolute_error: 2.7290 - val_loss: 13.0041 - val_mean_absolute_error: 2.8497
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 11.8854 - mean_absolute_error: 2.6807 - val_loss: 12.7241 - val_mean_absolute_error: 2.8102
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.9660 - mean_absolute_error: 2.6774 - val_loss: 13.5027 - val_mean_absolute_error: 2.9248
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.4859 - mean_absolute_error: 2.6338 - val_loss: 12.5832 - val_mean_absolute_error: 2.7782
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.6347 - mean_absolute_error: 2.6378 - val_loss: 12.5630 - val_mean_absolute_error: 2.7940
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 11.1468 - mean_absolute_error: 2.6013 - val_loss: 13.1928 - val_mean_absolute_error: 2.8642
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 11.1889 - mean_absolute_error: 2.5939 - val_loss: 12.6402 - val_mean_absolute_error: 2.7849
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.9597 - mean_absolute_error: 2.5651 - val_loss: 12.8330 - val_mean_absolute_error: 2.8359
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.6306 - mean_absolute_error: 2.5186 - val_loss: 12.8344 - val_mean_absolute_error: 2.8263
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.9501 - mean_absolute_error: 2.5550 - val_loss: 12.6745 - val_mean_absolute_error: 2.8011
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.4278 - mean_absolute_error: 2.4977 - val_loss: 12.7347 - val_mean_absolute_error: 2.7987
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.2382 - mean_absolute_error: 2.4806 - val_loss: 13.7504 - val_mean_absolute_error: 2.9373
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 10.2038 - mean_absolute_error: 2.4817 - val_loss: 13.0251 - val_mean_absolute_error: 2.8378
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.1476 - mean_absolute_error: 2.4575 - val_loss: 13.1251 - val_mean_absolute_error: 2.8503
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 10.0934 - mean_absolute_error: 2.4490 - val_loss: 13.0788 - val_mean_absolute_error: 2.8529
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9641 - mean_absolute_error: 2.4498 - val_loss: 13.1415 - val_mean_absolute_error: 2.8620
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9053 - mean_absolute_error: 2.4294 - val_loss: 13.1031 - val_mean_absolute_error: 2.8595
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6924 - mean_absolute_error: 2.4120 - val_loss: 12.8355 - val_mean_absolute_error: 2.8243
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9707 - mean_absolute_error: 2.4444 - val_loss: 13.1081 - val_mean_absolute_error: 2.8567
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6042 - mean_absolute_error: 2.3808 - val_loss: 13.4037 - val_mean_absolute_error: 2.9017
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5101 - mean_absolute_error: 2.3686 - val_loss: 13.1624 - val_mean_absolute_error: 2.8598
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3532 - mean_absolute_error: 2.3668 - val_loss: 13.1407 - val_mean_absolute_error: 2.8745
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7627 - mean_absolute_error: 1.6991
# All Sample MSE: 6.288061141967773
# All Sample MAE: 1.9177385568618774
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
#
# Timing:
# CPU times: total: 7.17 s
# Wall time: 14.6 s

# %%
plt.plot(h0.history['val_loss'])
plt.plot(h0.history['loss'])
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['validation','training'])
plt.title('Adam\nJena ANN')
plt.grid(color='white')
plt.show()

# %%
plt.plot(y_train)
plt.plot(p0.flatten())
plt.ylabel('Temperature [degC]')
plt.xlabel('Hour')
plt.legend(['training','prediction'])
plt.title('Adam\nJena ANN')
plt.grid(color='white')
plt.show()

# %%
plt.scatter(y_train,p0.flatten())
plt.ylabel('Estimated Temperature [degC]')
plt.xlabel('Measured Temperature [degC]')
plt.title('Adam\nJena ANN')
plt.grid(color='white')
plt.xlim([-22,38])
plt.ylim([-22,38])
plt.show()

# %% [markdown]
# ### Second Model, AdaGrad

# %%
# %%time
h1,p1=model_build('adagrad')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 104.6153 - mean_absolute_error: 8.3302 - val_loss: 65.3530 - val_mean_absolute_error: 6.5846
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 42.8065 - mean_absolute_error: 5.1630 - val_loss: 47.7758 - val_mean_absolute_error: 5.5337
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 35.4445 - mean_absolute_error: 4.6879 - val_loss: 38.3880 - val_mean_absolute_error: 4.9174
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 31.1961 - mean_absolute_error: 4.4255 - val_loss: 31.8909 - val_mean_absolute_error: 4.4600
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 27.8451 - mean_absolute_error: 4.1619 - val_loss: 27.8419 - val_mean_absolute_error: 4.1604
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 26.0549 - mean_absolute_error: 4.0288 - val_loss: 25.3318 - val_mean_absolute_error: 3.9646
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 25.0655 - mean_absolute_error: 3.9424 - val_loss: 23.3190 - val_mean_absolute_error: 3.8061
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.9583 - mean_absolute_error: 3.8577 - val_loss: 21.9179 - val_mean_absolute_error: 3.6841
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 23.1206 - mean_absolute_error: 3.7839 - val_loss: 20.8040 - val_mean_absolute_error: 3.5866
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.6773 - mean_absolute_error: 3.7430 - val_loss: 19.9657 - val_mean_absolute_error: 3.5129
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.8870 - mean_absolute_error: 3.6675 - val_loss: 19.1482 - val_mean_absolute_error: 3.4412
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 21.5776 - mean_absolute_error: 3.6544 - val_loss: 18.5167 - val_mean_absolute_error: 3.3837
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.3680 - mean_absolute_error: 3.5420 - val_loss: 18.0551 - val_mean_absolute_error: 3.3428
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.5946 - mean_absolute_error: 3.5556 - val_loss: 17.6060 - val_mean_absolute_error: 3.2992
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.9780 - mean_absolute_error: 3.5259 - val_loss: 17.2650 - val_mean_absolute_error: 3.2640
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 20.0100 - mean_absolute_error: 3.5111 - val_loss: 16.9006 - val_mean_absolute_error: 3.2309
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.4066 - mean_absolute_error: 3.4565 - val_loss: 16.6124 - val_mean_absolute_error: 3.2041
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.0335 - mean_absolute_error: 3.4114 - val_loss: 16.2930 - val_mean_absolute_error: 3.1743
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.2973 - mean_absolute_error: 3.4479 - val_loss: 16.0915 - val_mean_absolute_error: 3.1505
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.7661 - mean_absolute_error: 3.3880 - val_loss: 15.7282 - val_mean_absolute_error: 3.1184
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.3893 - mean_absolute_error: 3.3647 - val_loss: 15.5524 - val_mean_absolute_error: 3.1014
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.6026 - mean_absolute_error: 3.3871 - val_loss: 15.3172 - val_mean_absolute_error: 3.0804
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.1921 - mean_absolute_error: 3.3416 - val_loss: 15.1390 - val_mean_absolute_error: 3.0670
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.1489 - mean_absolute_error: 3.3346 - val_loss: 15.0113 - val_mean_absolute_error: 3.0522
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9084 - mean_absolute_error: 3.3092 - val_loss: 14.8287 - val_mean_absolute_error: 3.0344
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.9550 - mean_absolute_error: 3.3037 - val_loss: 14.7013 - val_mean_absolute_error: 3.0218
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6330 - mean_absolute_error: 3.3124 - val_loss: 14.5575 - val_mean_absolute_error: 3.0054
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.5891 - mean_absolute_error: 3.2922 - val_loss: 14.3880 - val_mean_absolute_error: 2.9936
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.7140 - mean_absolute_error: 3.3033 - val_loss: 14.2820 - val_mean_absolute_error: 2.9810
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.2686 - mean_absolute_error: 3.2523 - val_loss: 14.1502 - val_mean_absolute_error: 2.9672
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0607 - mean_absolute_error: 3.2318 - val_loss: 14.0936 - val_mean_absolute_error: 2.9647
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.1325 - mean_absolute_error: 3.2479 - val_loss: 13.9982 - val_mean_absolute_error: 2.9547
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10.9763 - mean_absolute_error: 2.5993
# All Sample MSE: 11.758960723876953
# All Sample MAE: 2.6909642219543457
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 821us/step
#
#
# Timing:
# CPU times: total: 4.45 s
# Wall time: 9.51 s

# %% [markdown]
# ### Third Model, Stochastic Gradient Descent with Nesterov Momentum

# %%
opt012=tf.keras.optimizers.SGD(momentum=0.5,
                               nesterov=True,
                               name='nSGD'
                              )

# %%
# %%time
h2,p2=model_build(opt012)
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: nan - mean_absolute_error: nan
# All Sample MSE: nan
# All Sample MAE: nan
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 791us/step
#
#
# Timing:
# CPU times: total: 3.89 s
# Wall time: 8.93 s

# %% [markdown]
# ### Fourth Model, Root Mean Squared Propagation

# %%
# %%time
h3,p3=model_build('rmsprop')
# Out:
# History Match:
# Epoch 1/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 49.1596 - mean_absolute_error: 5.3055 - val_loss: 20.3307 - val_mean_absolute_error: 3.5588
# Epoch 2/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.1888 - mean_absolute_error: 3.4199 - val_loss: 14.3671 - val_mean_absolute_error: 3.0064
# Epoch 3/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.5296 - mean_absolute_error: 3.2657 - val_loss: 14.4660 - val_mean_absolute_error: 2.9923
# Epoch 4/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.5290 - mean_absolute_error: 3.1747 - val_loss: 13.7721 - val_mean_absolute_error: 2.9291
# Epoch 5/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.8424 - mean_absolute_error: 3.0172 - val_loss: 12.9741 - val_mean_absolute_error: 2.8358
# Epoch 6/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.6413 - mean_absolute_error: 2.9797 - val_loss: 13.1635 - val_mean_absolute_error: 2.8689
# Epoch 7/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.3487 - mean_absolute_error: 2.8492 - val_loss: 13.5975 - val_mean_absolute_error: 2.8821
# Epoch 8/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.1750 - mean_absolute_error: 2.8280 - val_loss: 15.1900 - val_mean_absolute_error: 3.0510
# Epoch 9/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.4350 - mean_absolute_error: 2.8478 - val_loss: 13.0333 - val_mean_absolute_error: 2.8315
# Epoch 10/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.4686 - mean_absolute_error: 2.7531 - val_loss: 14.1352 - val_mean_absolute_error: 2.9742
# Epoch 11/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.2837 - mean_absolute_error: 2.7120 - val_loss: 13.3598 - val_mean_absolute_error: 2.8901
# Epoch 12/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.4438 - mean_absolute_error: 2.7485 - val_loss: 12.7086 - val_mean_absolute_error: 2.7941
# Epoch 13/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.8881 - mean_absolute_error: 2.6788 - val_loss: 13.4033 - val_mean_absolute_error: 2.8924
# Epoch 14/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.6901 - mean_absolute_error: 2.6402 - val_loss: 14.1241 - val_mean_absolute_error: 2.9553
# Epoch 15/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.7244 - mean_absolute_error: 2.6620 - val_loss: 13.5953 - val_mean_absolute_error: 2.9008
# Epoch 16/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.7168 - mean_absolute_error: 2.6351 - val_loss: 14.0356 - val_mean_absolute_error: 2.9656
# Epoch 17/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2711 - mean_absolute_error: 2.5995 - val_loss: 12.5064 - val_mean_absolute_error: 2.7902
# Epoch 18/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.5806 - mean_absolute_error: 2.5353 - val_loss: 12.9641 - val_mean_absolute_error: 2.8297
# Epoch 19/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7748 - mean_absolute_error: 2.5279 - val_loss: 16.9251 - val_mean_absolute_error: 3.2738
# Epoch 20/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.0663 - mean_absolute_error: 2.5731 - val_loss: 14.8373 - val_mean_absolute_error: 3.0630
# Epoch 21/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9745 - mean_absolute_error: 2.5660 - val_loss: 13.2997 - val_mean_absolute_error: 2.8706
# Epoch 22/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.8974 - mean_absolute_error: 2.5408 - val_loss: 13.4092 - val_mean_absolute_error: 2.8911
# Epoch 23/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3384 - mean_absolute_error: 2.4853 - val_loss: 14.6796 - val_mean_absolute_error: 3.0217
# Epoch 24/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.4711 - mean_absolute_error: 2.5024 - val_loss: 13.5875 - val_mean_absolute_error: 2.9010
# Epoch 25/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9100 - mean_absolute_error: 2.4267 - val_loss: 12.6853 - val_mean_absolute_error: 2.8263
# Epoch 26/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0493 - mean_absolute_error: 2.4521 - val_loss: 12.6025 - val_mean_absolute_error: 2.8017
# Epoch 27/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6454 - mean_absolute_error: 2.4031 - val_loss: 12.8847 - val_mean_absolute_error: 2.8339
# Epoch 28/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8227 - mean_absolute_error: 2.4203 - val_loss: 13.0125 - val_mean_absolute_error: 2.8638
# Epoch 29/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5966 - mean_absolute_error: 2.3937 - val_loss: 13.6994 - val_mean_absolute_error: 2.9423
# Epoch 30/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9542 - mean_absolute_error: 2.4391 - val_loss: 12.7952 - val_mean_absolute_error: 2.8260
# Epoch 31/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8449 - mean_absolute_error: 2.4246 - val_loss: 14.4708 - val_mean_absolute_error: 3.0096
# Epoch 32/32
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6912 - mean_absolute_error: 2.4012 - val_loss: 12.9763 - val_mean_absolute_error: 2.8463
#
#
# Evaluate Model:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9789 - mean_absolute_error: 2.0482
# All Sample MSE: 7.709918022155762
# All Sample MAE: 2.1422853469848633
#
#
# Make Predictions:
# 726/726 ━━━━━━━━━━━━━━━━━━━━ 1s 804us/step
#
#
# Timing:
# CPU times: total: 3.73 s
# Wall time: 8.72 s

# %%
plt.plot(h0.history['val_loss'])
plt.plot(h1.history['val_loss'])
plt.plot(h2.history['val_loss'])
plt.plot(h3.history['val_loss'])
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('Jena ANN')
plt.grid(color='white')
plt.show()

# %%
plt.plot(h0.history['val_loss'])
plt.plot(h1.history['val_loss'])
plt.plot(h2.history['val_loss'])
plt.plot(h3.history['val_loss'])
plt.ylabel('Mean Square Error')
plt.xlabel('Epoch')
plt.legend(['Adam','AdaGrad','SGD+Nest','RMSProp'])
plt.title('Jena ANN')
plt.ylim([10,20])
plt.grid(color='white')
plt.show()

# %% [markdown]
# ### Model Summary

# %%
m=model_core()
m.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ normalization (Normalization)        │ (None, 128, 11)             │              23 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 1408)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 64)                  │          90,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 92,312 (360.60 KB)
#  Trainable params: 92,289 (360.50 KB)
#  Non-trainable params: 23 (96.00 B)
